# %%
import re
import sys
import getopt
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.stem.porter import PorterStemmer
from sklearn import svm

# %%
import pdfplumber
path = 'C:/Users/wsy/Desktop/Resume/SDE/'
#path = 'C:/Users/wsy/Desktop/'
with pdfplumber.open(path + 'CV-Shiyu Wang.pdf') as rpdf:
    first_page = rpdf.pages[0]
    cv_pdf = first_page.extract_text()

# %%
all_stopwords = stopwords.words('english')

# %%
for i in range(len(cv_pdf)):
    if not cv_pdf[i].isalpha():
        cv_pdf = cv_pdf.replace(cv_pdf[i],' ')
cv_pdf = cv_pdf.lower().split()

ps = PorterStemmer()
temp = []
for j in range(len(cv_pdf)):
    if not cv_pdf[j] in all_stopwords:
        temp.append(ps.stem(cv_pdf[j]))
temp = ' '.join(temp)
cv_pdf = temp
print(cv_pdf)
# Out:
# shiyu wang w th st apt new york ny sw columbia edu 王诗雨 linkedin educ columbia univers columbia engin new york ny ms electr engin gpa cours machin learn statist learn digit signal process advanc big data ai expect dec xidian univers school electron engin xi cn beng electron inform engin gpa top sep jul honor first prize scholarship second prize scholarship outstand student award outstand graduat award outstand graduat project thesi skill program c r vhdl assembl languag html simulink profici matlab python softwar framework vmware matlab keil r studio ide spark sklearn kera languag chines english french research experi research bodi activ base wireless sens commun system particip xidian univers advisor xi yang lectur mar jun built wireless sens commun system support sdr correct center frequenc gather vital sign design filter algorithm includ fir filter trigger mechan wavelet transform featur extract bpm calcul optim algorithm adjust paramet improv measur accuraci heartbeat rate make hypothesi envelop respir waveform contain heartbeat inform verifi simul award outstand graduat project thesi xidian univers project experi job recommend system jan use spark sql extract inform text file pars data csv file convert text vector tf idf build svm classifi use sklearn predict job type provid career suggest recommend top k job applic base cosin similar applic job descript studi speaker recognit oct dec record data contain variou speak content differ environ input implement mfcc algorithm extract featur execut vqlbg algorithm knn algorithm match featur realiz speaker recognit function compar vqlbg knn algorithm compar studi car evalu dataset use differ ml method oct dec clean car evalu data set convert nomin attribut numer attribut min max normal built naïv bay mlp ann svm radial kernel knn decis tree random forest model respect process data set compar analyz result use differ ml method highest averag accuraci achiev knn method design visual sudoku game c linux jun jul form initi oper interfac build grid toggl function design number select interfac link libsx graphic librari linux design test algorithm realiz sudoku game realiz difficulti level

# %%
path = 'C:/Users/wsy/Desktop/ELEN6895/project/project/Data/processed_data.csv'
jobs = pd.read_csv(path)
#jobs = np.array(jobs)
#print(jobs[0])

# %%
tf = TfidfVectorizer()
from sklearn.model_selection import train_test_split

trainx = tf.fit_transform(jobs["Description"])
trainy = jobs["Query"]
#trainx = tf.fit_transform(jobs[:,1])
#trainy = jobs[:,0]
x_train, x_test, y_train, y_test = train_test_split(trainx, trainy, test_size = 0.25, random_state = 0)

# %%
#trainx.toarray()
tf.get_feature_names()
# Out:
# ['aa',
#  'aaa',
#  'aaae',
#  'aaai',
#  'aabb',
#  'aac',
#  'aachen',
#  'aaco',
#  'aacrao',
#  'aad',
#  'aadp',
#  'aadskin',
#  'aae',
#  'aafp',
#  'aag',
#  'aai',
#  'aam',
#  'aamc',
#  'aamd',
#  'aamhr',
#  'aami',
#  'aan',
#  'aanapisi',
#  'aao',
#  'aap',
#  'aaptiv',
#  'aar',
#  'aarp',
#  'aashto',
#  'aasp',
#  'aatb',
#  'aaw',
#  'aayzpc',
#  'ab',
#  'aba',
#  'abag',
#  'abaku',
#  'abandon',
#  'abap',
#  'abat',
#  'abb',
#  'abbott',
#  'abbrevi',
#  'abbv',
#  'abbvi',
#  'abc',
#  'abcam',
#  'abcmous',
#  'abcp',
#  'abd',
#  'abdomin',
#  'abel',
#  'aber',
#  'aberdeen',
#  'aberr',
#  'abet',
#  'abhow',
#  'abi',
#  'abid',
#  'abil',
#  'abila',
#  'abilifi',
#  'abilitylab',
#  'abilityto',
#  'abilti',
#  'abiltiy',
#  'abington',
#  'abingtonsport',
#  'abinitio',
#  'abiot',
#  'abitliy',
#  'abl',
#  'ableto',
#  'ablil',
#  'abliti',
#  'abloy',
#  'abm',
#  'abn',
#  'abnorm',
#  'aboard',
#  'abog',
#  'aborigin',
#  'abort',
#  'abound',
#  'aboutadob',
#  'aboutagil',
#  'aboutdesign',
#  'aboutu',
#  'abovement',
#  'abras',
#  'abreast',
#  'abroad',
#  'absenc',
#  'absent',
#  'absente',
#  'absolut',
#  'absorb',
#  'absorpt',
#  'abstract',
#  'abstractli',
#  'abstractor',
#  'abund',
#  'abus',
#  'abutt',
#  'ac',
#  'aca',
#  'academ',
#  'academi',
#  'academia',
#  'academician',
#  'academicwork',
#  'acadm',
#  'acalog',
#  'acanc',
#  'acap',
#  'acar',
#  'acat',
#  'acc',
#  'accc',
#  'acccount',
#  'accel',
#  'accela',
#  'acceler',
#  'acceleromet',
#  'accellion',
#  'accent',
#  'accentur',
#  'acceo',
#  'accept',
#  'access',
#  'accessdata',
#  'accessequ',
#  'accessexperi',
#  'accessibilitystrong',
#  'accession',
#  'accessori',
#  'accessthoughtwork',
#  'accid',
#  'accident',
#  'acciona',
#  'acció',
#  'acclaim',
#  'acclara',
#  'acclim',
#  'acco',
#  'accolad',
#  'accommod',
#  'accommodationrequest',
#  'accomod',
#  'accompani',
#  'accomplish',
#  'accor',
#  'accord',
#  'accordingli',
#  'account',
#  'accountabilit',
#  'accountpotenti',
#  'accpac',
#  'accr',
#  'accred',
#  'accredid',
#  'accredit',
#  'accreditor',
#  'accret',
#  'accru',
#  'accrual',
#  'accsc',
#  'acct',
#  'accudata',
#  'accufit',
#  'accultur',
#  'accumark',
#  'accumen',
#  'accumul',
#  'accumulo',
#  'accur',
#  'accuraci',
#  'accuray',
#  'accurint',
#  'accuryn',
#  'accus',
#  'accustom',
#  'accutrac',
#  'acd',
#  'acdb',
#  'ace',
#  'acelerada',
#  'acer',
#  'acetylen',
#  'acf',
#  'acfc',
#  'acg',
#  'acgh',
#  'acgm',
#  'acgov',
#  'ach',
#  'achiev',
#  'achil',
#  'achitectur',
#  'achiv',
#  'achsnatl',
#  'aci',
#  'acid',
#  'acidifi',
#  'acio',
#  'acit',
#  'acknowledg',
#  'acl',
#  'aclu',
#  'acm',
#  'acma',
#  'acmi',
#  'acmp',
#  'acmt',
#  'acmx',
#  'aco',
#  'acord',
#  'acorss',
#  'acoso',
#  'acoust',
#  'acp',
#  'acquaint',
#  'acquia',
#  'acquir',
#  'acquisit',
#  'acr',
#  'acrobat',
#  'acroni',
#  'acronym',
#  'acropoli',
#  'across',
#  'acrossdisciplin',
#  'acrossliter',
#  'acrp',
#  'acryl',
#  'acsa',
#  'acsl',
#  'acsm',
#  'acsp',
#  'act',
#  'actc',
#  'actelion',
#  'actfl',
#  'actia',
#  'actic',
#  'actim',
#  'action',
#  'actionabilti',
#  'actionablerecommend',
#  'actionkit',
#  'actionscript',
#  'activ',
#  'activecampaign',
#  'activecor',
#  'activedirectori',
#  'activemq',
#  'activerecord',
#  'activerol',
#  'activesync',
#  'activetransf',
#  'activi',
#  'actividad',
#  'activis',
#  'activisionblizzard',
#  'activisionʹ',
#  'activist',
#  'activit',
#  'activitiesassist',
#  'activitiesexecut',
#  'activitiesrequir',
#  'activitiesresearch',
#  'activitiestest',
#  'activitiesto',
#  'activstyl',
#  'actor',
#  'actsa',
#  'actual',
#  'actuari',
#  'actuat',
#  'acuiti',
#  'acumatica',
#  'acumen',
#  'acumensolut',
#  'acunetix',
#  'acuren',
#  'acustom',
#  'acut',
#  'acuta',
#  'acv',
#  'acx',
#  'acxiom',
#  'acxiomequifax',
#  'ad',
#  'ada',
#  'adaaa',
#  'adadelta',
#  'adag',
#  'adam',
#  'adapt',
#  'adaptor',
#  'adarequest',
#  'adaytoref',
#  'adb',
#  'adc',
#  'adcent',
#  'adcom',
#  'add',
#  'addenda',
#  'addendum',
#  'addepar',
#  'addi',
#  'addict',
#  'addison',
#  'addit',
#  'additin',
#  'additioanl',
#  'additioanlli',
#  'addm',
#  'addon',
#  'address',
#  'addresse',
#  'addresss',
#  'adea',
#  'adelph',
#  'adept',
#  'adeptli',
#  'adeq',
#  'adequ',
#  'adequaci',
#  'ader',
#  'adf',
#  'adfdi',
#  'adh',
#  'adhd',
#  'adher',
#  'adheringto',
#  'adhes',
#  'adhoc',
#  'adi',
#  'adiabat',
#  'adida',
#  'adient',
#  'adirondack',
#  'adjac',
#  'adjoin',
#  'adjud',
#  'adjunct',
#  'adjust',
#  'adjut',
#  'adkar',
#  'adl',
#  'adld',
#  'adm',
#  'admi',
#  'admin',
#  'administ',
#  'administr',
#  'administrationappl',
#  'administrationcassandra',
#  'administratoreast',
#  'adminsitr',
#  'adminstr',
#  'admir',
#  'admiss',
#  'admit',
#  'admitt',
#  'admm',
#  'admob',
#  'ado',
#  'adoa',
#  'adob',
#  'adolesc',
#  'adometri',
#  'adop',
#  'adopt',
#  'adoptself',
#  'adoq',
#  'ador',
#  'adot',
#  'adp',
#  'adr',
#  'adroitli',
#  'adsens',
#  'adserv',
#  'adsi',
#  'adsp',
#  'adstock',
#  'adt',
#  'adtalem',
#  'adtech',
#  'adtf',
#  'adtrav',
#  'adu',
#  'aduc',
#  'adult',
#  'adulter',
#  'adulthood',
#  'adv',
#  'advanc',
#  'advanceddegre',
#  'advantag',
#  'advantest',
#  'advent',
#  'adventist',
#  'adventresourc',
#  'adventur',
#  'advers',
#  'adversari',
#  'advertis',
#  'advia',
#  'advic',
#  'advis',
#  'advise',
#  'advisor',
#  'advisori',
#  'advoc',
#  'advocaci',
#  'advocacyintern',
#  'adw',
#  'adweek',
#  'adwizz',
#  'adword',
#  'adxpos',
#  'ae',
#  'aec',
#  'aecom',
#  'aeda',
#  'aeea',
#  'aeg',
#  'aegi',
#  'aegion',
#  'aehf',
#  'aei',
#  'ael',
#  'aem',
#  'aema',
#  'aepa',
#  'aera',
#  'aerial',
#  'aero',
#  'aerodynam',
#  'aerogel',
#  'aeroh',
#  'aeronaut',
#  'aerosol',
#  'aerosolv',
#  'aerospac',
#  'aeruginosa',
#  'aesip',
#  'aesoln',
#  'aesolut',
#  'aesop',
#  'aesthet',
#  'aet',
#  'aetna',
#  'aeto',
#  'aex',
#  'af',
#  'afast',
#  'afb',
#  'afc',
#  'afcc',
#  'afd',
#  'afda',
#  'afduzl',
#  'afdx',
#  'afe',
#  'afeti',
#  'affair',
#  'affect',
#  'affecti',
#  'affection',
#  'affidavit',
#  'affili',
#  'affin',
#  'affinio',
#  'affinityit',
#  'affirm',
#  'affirmativeact',
#  'affirmit',
#  'affix',
#  'afflict',
#  'affluent',
#  'afford',
#  'affray',
#  'afg',
#  'afh',
#  'afi',
#  'afib',
#  'aficionado',
#  'afirmativa',
#  'afl',
#  'aflac',
#  'aflatoxin',
#  'afloat',
#  'afm',
#  'afman',
#  'afni',
#  'afo',
#  'aforement',
#  'afp',
#  'afraid',
#  'africa',
#  'african',
#  'afrl',
#  'afscm',
#  'afspc',
#  'aft',
#  'after',
#  'aftereffect',
#  'afterhour',
#  'afterload',
#  'aftermarket',
#  'aftermath',
#  'aftern',
#  'afternoon',
#  'aftersal',
#  'afterschool',
#  'afterthought',
#  'afterward',
#  'ag',
#  'agarw',
#  'agc',
#  'agco',
#  'age',
#  'agenc',
#  'agencieson',
#  'agencypersonnel',
#  'agencyth',
#  'agenda',
#  'agenet',
#  'agent',
#  'agentless',
#  'agero',
#  'aggreg',
#  'aggress',
#  'aggriev',
#  'agiel',
#  'agil',
#  'agilist',
#  'agilon',
#  'aglob',
#  'agn',
#  'agnost',
#  'ago',
#  'agon',
#  'agoura',
#  'agpm',
#  'agre',
#  'agreeabl',
#  'agreement',
#  'agribusi',
#  'agricultur',
#  'agrisci',
#  'agritech',
#  'agro',
#  'agrofresh',
#  'agroinformat',
#  'agronom',
#  'agronomi',
#  'agsci',
#  'agwat',
#  'agzp',
#  'ah',
#  'aha',
#  'ahca',
#  'ahccc',
#  'ahcp',
#  'ahe',
#  'ahead',
#  'ahem',
#  'ahern',
#  'ahfc',
#  'ahhmaz',
#  'ahi',
#  'ahj',
#  'ahl',
#  'ahm',
#  'ahmedani',
#  'ahold',
#  'ahp',
#  'ahr',
#  'ahrq',
#  'aht',
#  'ahu',
#  'ahv',
#  'ahwatuke',
#  'ai',
#  'aia',
#  'aiag',
#  'aib',
#  'aic',
#  'aicp',
#  'aicpa',
#  'aid',
#  'aidet',
#  'aidslifecycl',
#  'aie',
#  'aiezlb',
#  'aif',
#  'aig',
#  'ailment',
#  'aim',
#  'aimhir',
#  'aimia',
#  'aiml',
#  'aimot',
#  'ain',
#  'aint',
#  'aintain',
#  'aiop',
#  'aip',
#  'aipg',
#  'air',
#  'airbnb',
#  'airborn',
#  'airbu',
#  'airbustechn',
#  'aircard',
#  'aircast',
#  'aircraft',
#  'aircrew',
#  'airespr',
#  'airfar',
#  'airfield',
#  'airflow',
#  'airfram',
#  'airga',
#  'airgener',
#  'airgroup',
#  'airi',
#  'airlift',
#  'airlin',
#  'airmen',
#  'aironet',
#  'airplan',
#  'airport',
#  'airship',
#  'airsid',
#  'airspac',
#  'airspe',
#  'airtabl',
#  'airwatch',
#  'airwav',
#  'airway',
#  'airworthi',
#  'aisha',
#  'aisin',
#  'aisl',
#  'aisp',
#  'aistat',
#  'ait',
#  'aix',
#  'ajax',
#  'ajcc',
#  'ajilon',
#  'ajith',
#  'ak',
#  'aka',
#  'akamai',
#  'akana',
#  'akg',
#  'akhfqrb',
#  'akili',
#  'akima',
#  'akimaglobalservic',
#  'akka',
#  'akkroo',
#  'akn',
#  'akraya',
#  'aktion',
#  'akuna',
#  'akzonobel',
#  'al',
#  'ala',
#  'alabama',
#  'aladdin',
#  'alameda',
#  'alan',
#  'alarm',
#  'alaska',
#  'alaskan',
#  'alat',
#  'alb',
#  'albani',
#  'albeit',
#  'albert',
#  'alberta',
#  'alberto',
#  'albertson',
#  'albridg',
#  'albuquerqu',
#  'alc',
#  'alcatraz',
#  'alchemi',
#  'alchemist',
#  'alcohol',
#  'aldera',
#  'aldon',
#  'ale',
#  'alen',
#  'alert',
#  'alerton',
#  'alertsit',
#  'alessandro',
#  'alewif',
#  'alex',
#  'alexa',
#  'alexandria',
#  'alg',
#  'algebra',
#  'algo',
#  'algolog',
#  'algona',
#  'algonquin',
#  'algorithm',
#  'algorthm',
#  'algorythm',
#  'alhambra',
#  'ali',
#  'alia',
#  'alias',
#  'alibaba',
#  'alic',
#  'alien',
#  'alienag',
#  'alienvault',
#  'align',
#  'alignmentsubject',
#  'alignstar',
#  'alik',
#  'aliquot',
#  'alisha',
#  'alishar',
#  'aliv',
#  'alivecor',
#  'alixpartn',
#  'aliyun',
#  'alk',
#  'alkalin',
#  'alkami',
#  'alkyl',
#  'allair',
#  'allan',
#  'alleg',
#  'allegi',
#  'allen',
#  'allenai',
#  'allerg',
#  'allergan',
#  'allergen',
#  'allergi',
#  'allevi',
#  'alley',
#  'allfus',
#  'allgress',
#  'alli',
#  'allianc',
#  'alliant',
#  'alliantgroup',
#  'allianz',
#  'allig',
#  'allina',
#  'allman',
#  'allmana',
#  'allmodern',
#  'alloc',
#  'allot',
#  'allow',
#  'alloy',
#  'allscript',
#  'allspark',
#  'allstat',
#  'allstategoodlif',
#  'allstream',
#  'alltogeth',
#  'allyn',
#  'alm',
#  'alma',
#  'almond',
#  'almost',
#  'almt',
#  'aloha',
#  'alon',
#  'along',
#  'alongsid',
#  'alooma',
#  'alorica',
#  'alpha',
#  'alphabet',
#  'alphanumer',
#  'alpharetta',
#  'alphasight',
#  'alphen',
#  'alpin',
#  'alreadi',
#  'alsd',
#  'alsip',
#  'alsnet',
#  'also',
#  'alstar',
#  'alt',
#  'altair',
#  'altametr',
#  'altec',
#  'alter',
#  'altern',
#  'alterra',
#  'alteryx',
#  'although',
#  'altic',
#  'altiri',
#  'altitud',
#  'altium',
#  'altmetr',
#  'alto',
#  'altogeth',
#  'altoid',
#  'altruism',
#  'altsa',
#  'alum',
#  'aluminum',
#  'alumni',
#  'alvarez',
#  'alway',
#  'alwaysencrypt',
#  'alwayson',
#  'alzheim',
#  'am',
#  'ama',
#  'amalgam',
#  'amanda',
#  'amarillo',
#  'amass',
#  'amat',
#  'amateur',
#  'amaz',
#  'amazingli',
#  'amazon',
#  'amazonaw',
#  'ambari',
#  'ambassador',
#  'amber',
#  'ambient',
#  'ambigu',
#  'ambiguitypref',
#  'ambit',
#  'ambiti',
#  'ambler',
#  'ambonar',
#  'ambul',
#  'ambulatori',
#  'amc',
#  'amchart',
#  'amct',
#  'amd',
#  'amdahl',
#  'amdd',
#  'amdoc',
#  'amdp',
#  'ame',
#  'amedeu',
#  'amelia',
#  'amen',
#  'amend',
#  'amer',
#  'ameresco',
#  'america',
#  'american',
#  'americana',
#  'americanmuscl',
#  'americanredcross',
#  'americantruck',
#  'americorp',
#  'ameriflex',
#  'ameriga',
#  'amerihealth',
#  'amerihealthcarita',
#  'amerita',
#  'ameritrust',
#  'amersport',
#  'amex',
#  'amgen',
#  'amherst',
#  'ami',
#  'amic',
#  'amid',
#  'amidst',
#  'amigo',
#  'amk',
#  'aml',
#  'amlro',
#  'ammet',
#  'ammo',
#  'ammunit',
#  'amn',
#  'amna',
#  'amnesti',
#  'among',
#  'amongst',
#  'amongth',
#  'amorph',
#  'amount',
#  'amp',
#  'amphetamin',
#  'ampl',
#  'amplienc',
#  'amplif',
#  'amplifi',
#  'amplitud',
#  'ampscript',
#  'ampul',
#  'amput',
#  'ampute',
#  'ampv',
#  'amq',
#  'amqp',
#  'amr',
#  'amrock',
#  'amrutha',
#  'amruthad',
#  'amsterdam',
#  'amt',
#  'amtc',
#  'amtrak',
#  'amundsen',
#  'amus',
#  'amx',
#  'amysi',
#  'an',
#  'ana',
#  'anabsentemployeeor',
#  'anaconda',
#  'anadrom',
#  'anag',
#  'anaheim',
#  'anal',
#  'anali',
#  'analist',
#  'anallyt',
#  'analog',
#  'analogu',
#  'analy',
#  'analyit',
#  'analys',
#  'analysi',
#  'analysisand',
#  'analysisexperi',
#  'analysisjob',
#  'analysist',
#  'analysisunit',
#  'analyst',
#  'analystexperi',
#  'analyt',
#  'analytica',
#  'analyticai',
#  'analyticalprocess',
#  'analyticalsolut',
#  'analyticaltechniqu',
#  'analyticsmh',
#  'analyticsth',
#  'analyticswil',
#  'analytx',
#  'analyz',
#  'analyzepotenti',
#  'anandhan',
#  'anaplan',
#  'anaplanlov',
#  'anatom',
#  'anatomi',
#  'ancc',
#  'ancestr',
#  'ancestri',
#  'anchor',
#  'anchorag',
#  'ancient',
#  'ancil',
#  'ancillari',
#  'and',
#  'andaccount',
#  'andadv',
#  'andalign',
#  'andanali',
#  'andanalysi',
#  'andanalyt',
#  'andani',
#  'andar',
#  'andassumpt',
#  'andbenefit',
#  'andcan',
#  'andchart',
#  'andclos',
#  'andcommun',
#  'andcooper',
#  'andcross',
#  'andcumul',
#  'andcustom',
#  'anddeploy',
#  'anddiagnos',
#  'anddirect',
#  ...]

# %%
print(trainx)
# Out:
#   (0, 12019)	0.04091878244524667
#   (0, 4343)	0.026309411725629242
#   (0, 19314)	0.015455117482896814
#   (0, 8792)	0.03251063501348185
#   (0, 4887)	0.02203467873894483
#   (0, 23563)	0.030128574654954367
#   (0, 26624)	0.015581754916877454
#   (0, 524)	0.017804595346764956
#   (0, 6700)	0.01415793018689021
#   (0, 9982)	0.025107803335422986
#   (0, 17821)	0.01660742595601531
#   (0, 17817)	0.014261056305639678
#   (0, 22245)	0.017312081141959174
#   (0, 8664)	0.023222709778205227
#   (0, 11839)	0.01773626425556274
#   (0, 9968)	0.03478613856334019
#   (0, 20744)	0.017079874874884618
#   (0, 4755)	0.01698849458990274
#   (0, 20205)	0.01678057490060187
#   (0, 20650)	0.03568658893091265
#   (0, 27544)	0.018266129346622653
#   (0, 5063)	0.021896250897634893
#   (0, 20083)	0.01805076009461279
#   (0, 7901)	0.0384772004616498
#   (0, 8194)	0.014644515492607112
#   :	:
#   (12999, 19755)	0.026880277419791775
#   (12999, 13928)	0.036158944902061785
#   (12999, 8599)	0.05371057984962201
#   (12999, 21848)	0.019264242769798247
#   (12999, 19453)	0.022680966595404764
#   (12999, 22688)	0.02476118248770831
#   (12999, 8105)	0.015229390598227345
#   (12999, 4724)	0.018373888603845027
#   (12999, 12507)	0.02687692317240205
#   (12999, 4506)	0.0474461960939976
#   (12999, 24535)	0.08837890481169465
#   (12999, 14939)	0.02860103451536369
#   (12999, 4829)	0.012867745686398754
#   (12999, 12425)	0.027500862048491007
#   (12999, 3164)	0.016767831637878077
#   (12999, 13954)	0.055142887391950765
#   (12999, 23557)	0.02688103958302714
#   (12999, 1242)	0.02022833058880113
#   (12999, 7177)	0.08020169858162132
#   (12999, 19558)	0.03406088236881679
#   (12999, 20716)	0.015066456479954731
#   (12999, 23044)	0.02001174208719855
#   (12999, 24468)	0.09518617520082652
#   (12999, 27617)	0.04316103334928325
#   (12999, 5963)	0.10888378131263814

# %%
'''
from sklearn.preprocessing import StandardScaler
sc = StandardScaler(with_mean=False)
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

import sklearn
x_train = sklearn.preprocessing.normalize(x_train)
x_test = sklearn.preprocessing.normalize(x_test)
'''

# %%
y_test

# %%
'''
clf = svm.LinearSVC()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
'''

# %%
'''
clf = svm.SVC(decision_function_shape='ovo')
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
'''
# Out:
# "\nclf = svm.SVC(decision_function_shape='ovo')\nclf.fit(x_train, y_train)\ny_pred = clf.predict(x_test)\n"

# %%
'''
from sklearn.ensemble import RandomForestClassifier
regr = RandomForestClassifier(max_depth=2, random_state=0)
regr.fit(x_train, y_train)
'''
# Out:
# RandomForestClassifier(max_depth=2, random_state=0)

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=20)
neigh.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=100)

# %%
y_pred = neigh.predict(x_test)

# %%
#Evaluation
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.4307692307692308

# %%
#test_x = tf.transform([cv_pdf])
#test_y = clf.predict(test_x)
#test_y[0]
