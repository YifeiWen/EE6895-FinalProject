# %%
import numpy as np
import pandas as pd
import wordcloud
from matplotlib import pyplot as plt

# %%
dataset = pd.read_csv("../../data/job_data.csv")

# %%
dataset.head(5)
# Out:
#                                        advertiserurl  \
# 0  https://www.dice.com/jobs/detail/AUTOMATION-TE...
# 1  https://www.dice.com/jobs/detail/Information-S...
# 2  https://www.dice.com/jobs/detail/Business-Solu...
# 3  https://www.dice.com/jobs/detail/Java-Develope...
# 4  https://www.dice.com/jobs/detail/DevOps-Engine...
#
#                              company  \
# 0  Digital Intelligence Systems, LLC
# 1  University of Chicago/IT Services
# 2               Galaxy Systems, Inc.
# 3                      TransTech LLC
# 4                   Matrix Resources
#
#                             employmenttype_jobstatus  \
# 0  C2H Corp-To-Corp, C2H Independent, C2H W2, 3 M...
# 1                                          Full Time
# 2                                          Full Time
# 3                                          Full Time
# 4                                          Full Time
#
#                                       jobdescription               jobid  \
# ...

# %%
len(dataset)
# Out:
# 22000

# %%
dataset['joblocation_address'].unique()
# Out:
# array(['Atlanta, GA', 'Chicago, IL', 'Schaumburg, IL', ...,
#        'Pleasanton,, CA', 'Merced, CA', 'East Palo Alto, CA'],
#       dtype=object)

# %%
wc = wordcloud.WordCloud(background_color="white", width = 800, height = 400)
wc.generate_from_frequencies(dataset['joblocation_address'].value_counts())
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 799.5, 399.5, -0.5)

# %%
dataset['joblocation_address'].value_counts()
# Out:
# New York, NY            1368
# Atlanta, GA             1245
# San Francisco, CA        886
# Seattle, WA              661
# Boston, MA               606
#                         ...
# Forsyth, GA                1
# North Wales, PA            1
# Rancho Cucamonga, CA       1
# Commerce, MI               1
# San Francisco,             1
# Name: joblocation_address, Length: 1581, dtype: int64

# %%
dataset['joblocation_address']
# Out:
# 0              Atlanta, GA
# 1              Chicago, IL
# 2           Schaumburg, IL
# 3          Bolingbrook, IL
# 4              Atlanta, GA
#                ...
# 21995          Oakland, CA
# 21996    San Francisco, CA
# 21997    San Francisco, CA
# 21998          Oakland, CA
# 21999      Santa Clara, CA
# Name: joblocation_address, Length: 22000, dtype: object

# %%
#chose location in UI
city = 'New York'
state_abbre = 'NY'
address = city + ',' + ' ' + state_abbre
dataset.loc[dataset['joblocation_address'] == address]
# Out:
#                                            advertiserurl  \
# 8      https://www.dice.com/jobs/detail/Front-End-Dev...
# 55     https://www.dice.com/jobs/detail/Senior-Full-S...
# 70     https://www.dice.com/jobs/detail/Linux-Enginee...
# 71     https://www.dice.com/jobs/detail/Front-end%252...
# 74     https://www.dice.com/jobs/detail/Infrastructur...
# ...                                                  ...
# 20123  https://www.dice.com/jobs/detail/Electronic-Tr...
# 20135  https://www.dice.com/jobs/detail/C%252B%252B-R...
# 20138  https://www.dice.com/jobs/detail/OOP-%2526%252...
# 20159  https://www.dice.com/jobs/detail/Javascript-De...
# 20190  https://www.dice.com/jobs/detail/Sailpoint-Sol...
#
#                                       company  \
# 8                                   Genesis10
# 55                                  Genesis10
# 70                                  Genesis10
# 71        Fahrenheit IT Staffing & Consulting
# ...
